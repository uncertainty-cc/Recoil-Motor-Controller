# %%
import numpy as np
from matplotlib import pyplot as plt

from matplotlib import animation
from IPython.display import HTML

plt.rcParams['figure.figsize'] = [16, 10]

# %%
class SimMotor:
    def __init__(self):
        self.position = 0
        self.velocity = 0
        self.acceleration = 0
        self.inertia = 1
    
    def update(self, dt, torque):
        self.acceleration = torque / self.inertia
        self.velocity += self.acceleration * dt
        self.position += self.velocity * dt

class Environment:
    def __init__(self):
        self.motor = SimMotor()
        self.dt = 1 / 1e3
        self.t = 0
        self.observation = {}
        
    def step(self, inputs):
        self.motor.update(self.dt, inputs["motor_torque"])
        self.t += self.dt
        
        self.observation["motor_position"] = self.motor.position
        self.observation["motor_velocity"] = self.motor.velocity
        self.observation["motor_acceleration"] = self.motor.acceleration

    def getTimeHistory(self):
        self.t_arr = np.linspace(0, self.t, int(self.t // self.dt))
        return self.t_arr
        
env = Environment()

inputs = {
    "motor_motor_torque": 0.1
}

pos_arr = []

for i in range(100):
    inputs["motor_torque"] = 0.1
    env.step(inputs)

    print(env.observation["motor_position"])
    pos_arr.append(env.observation["motor_position"])

t_arr = env.getTimeHistory()
# Out:
# 1.0000000000000001e-07
# 3.0000000000000004e-07
# 6.000000000000001e-07
# 1.0000000000000002e-06
# 1.5e-06
# 2.1000000000000002e-06
# 2.8000000000000003e-06
# 3.6000000000000003e-06
# 4.5e-06
# 5.5e-06
# 6.6e-06
# 7.8e-06
# 9.100000000000001e-06
# 1.0500000000000001e-05
# 1.2000000000000002e-05
# 1.3600000000000002e-05
# 1.5300000000000003e-05
# 1.7100000000000002e-05
# 1.9000000000000004e-05
# 2.1000000000000006e-05
# 2.3100000000000006e-05
# 2.5300000000000005e-05
# 2.7600000000000007e-05
# 3.0000000000000008e-05
# 3.2500000000000004e-05
# 3.5100000000000006e-05
# 3.7800000000000004e-05
# 4.0600000000000004e-05
# 4.35e-05
# 4.65e-05
# 4.96e-05
# 5.2799999999999996e-05
# 5.6099999999999995e-05
# 5.9499999999999996e-05
# 6.3e-05
# 6.659999999999999e-05
# 7.029999999999999e-05
# 7.409999999999999e-05
# 7.799999999999999e-05
# 8.199999999999999e-05
# 8.609999999999998e-05
# 9.029999999999997e-05
# 9.459999999999997e-05
# 9.899999999999997e-05
# 0.00010349999999999997
# ...

# %%
plt.plot(t_arr, pos_arr, label="Position")
plt.legend(loc="upper right")
plt.title("Motion History")
# Out:
# Text(0.5, 1.0, 'Linear Voltage')
